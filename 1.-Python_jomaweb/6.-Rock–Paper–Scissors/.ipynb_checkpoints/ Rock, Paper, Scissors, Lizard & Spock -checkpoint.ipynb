# %%
import random

# definig game variables
gestures = ["rock", "paper", "scissors", "lizard", "spock"]


user_choices = ""
cpu_choice = ""

rounds_choice = []
rounds = rounds_choice
cpu_score = 0
user_score = 0
tie = 0






#defining user move 
def user_input():
    while True:
        print ("Please type your choose: rock, paper, scissors, spock or lizard.")
        user = input()
        global user_choices 
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
#defining cpu move as random
def cpu_random():
    global cpu_choice 
    cpu_choice = random.choice(gestures)
    print ("The computer choose:", cpu_choice)            
            

#definig the rounds to play

def rounds_number():
    while True:
        print ("Please type the number of rounds you want to play. Choose odd numbers.")
        number = input()
        global rounds_choice 
        rounds_choice = number
        print ("You choose:" + rounds_choice[0] + "You need to win" + (rounds_choice[0] - 2) + "rounds to defeat the computer" )
          


    
rounds_number()


while rounds < rounds_choice: 
    rounds += 1
    print ("Round", rounds, "of", rounds_choice, "rounds.")  
    user_input()
    cpu_random()
    print ("Computer:", cpu_choice, "User:",  user_choices )
    
    
    
    
    if user_choices == "rock" and (cpu_choice == "scissors" or cpu_choice == "lizar"):
        user_score += 1
        print ("The user wins the round ! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and (cpu_choice == "paper" or cpu_choice == "lizard"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and (cpu_choice == "rock" or cpu_choice == "spock"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
     
    elif user_choices == "spock" and (cpu_choice == "rock" or cpu_choice == "scissors"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)   
     
    elif user_choices == "lizard" and (cpu_choice == "paper" or cpu_choice == "spock"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
        
    elif (user_choices == "scissors" or user_choices == "spock") and cpu_choice == "paper":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif (user_choices == "paper" or user_choices == "lizard" ) and cpu_choice == "scissors":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif (user_choices == "rock" or user_choices == "spock") and cpu_choice == "paper":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
     
    elif (user_choices == "rock" or user_choices == "scissors") and cpu_choice == "spock":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
 
    elif (user_choices == "spock" or user_choices == "paper") and cpu_choice == "lizard":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score) 
 
       
# Print the winner of the game based on who won more rounds
    
    if rounds == (rounds_choice - 2) and (user_score > cpu_score):
        print ("The user wins the game! Computer score:", cpu_score, "   User score:", user_score)   
        break         
    elif rounds == (rounds_choice - 2) and (user_score < cpu_score):
        print ("The computer wins the game!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
    elif user_choices == cpu_choice:
        tie += 1
        print ("tie")
    elif tie == rounds_choice:
        print ("The game is tied! Great job!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break

# %%
import random

# definig game variables
gestures = ["rock", "paper", "scissors", "lizard", "spock"]


user_choices = ""
cpu_choice = ""

rounds_choice = []
rounds = 0
cpu_score = 0
user_score = 0
tie = 0






#defining user move 
def user_input():
    while True:
        print ("Please type your choose: rock, paper, scissors, spock or lizard.")
        user = input()
        global user_choices 
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
#defining cpu move as random
def cpu_random():
    global cpu_choice 
    cpu_choice = random.choice(gestures)
    print ("The computer choose:", cpu_choice)            
            

#definig the rounds to play

def number():
    while True:
        try:
            print ("Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).")
            number = input()
            if int(number) is False:
                print ("Please, type an odd number")
            elif int(number) % 2 == 0:
                print ("Please, type an odd number")
            else:
                print ("You choose " + str(number) + " rounds to play. Good luck!" )
                global rounds_choice 
                rounds_choice = int(number) 
                break
        except ValueError: 
            print ("Please, type an odd number")
    



#user_input()

#cpu_random()    
number()

while rounds < rounds_choice: 
    rounds += 1
    print ("Round:", rounds)  
    user_input()
    cpu_random()
    print ("Computer:", cpu_choice, "User:",  user_choices )
    
    if user_choices == "rock" and (cpu_choice == "scissors" or cpu_choice == "lizar"):
        user_score += 1
        print ("The user wins the round ! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and (cpu_choice == "paper" or cpu_choice == "lizard"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and (cpu_choice == "rock" or cpu_choice == "spock"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
     
    elif user_choices == "spock" and (cpu_choice == "rock" or cpu_choice == "scissors"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)   
     
    elif user_choices == "lizard" and (cpu_choice == "paper" or cpu_choice == "spock"):
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
        
    elif (user_choices == "scissors" or user_choices == "spock") and cpu_choice == "paper":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif (user_choices == "paper" or user_choices == "lizard" ) and cpu_choice == "scissors":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif (user_choices == "rock" or user_choices == "spock") and cpu_choice == "paper":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
     
    elif (user_choices == "rock" or user_choices == "scissors") and cpu_choice == "spock":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
 
    elif (user_choices == "spock" or user_choices == "paper") and cpu_choice == "lizard":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score) 
 
        
# Print the winner of the game based on who won more rounds
    if (rounds < rounds_choice) and (user_choices == cpu_choice):
        tie += 1
        print ("tie")
    elif rounds == rounds_choice and (user_score > cpu_score):
        print ("The user wins the game! Computer score:", cpu_score, "   User score:", user_score)   
        break         
    elif rounds == rounds_choice and (user_score < cpu_score):
        print ("The computer wins the game!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
    elif rounds == rounds_choice and (user_score == cpu_score):
        print ("The game is tied! Great job!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
    elif tie == (rounds_choice / 2) +1:
        print ("The game is tied! Great job!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
# Out:
# Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).
# l
# Please, type an odd number
# Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).
# 2
# Please, type an odd number
# Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).
# 3
# You choose 3 rounds to play. Good luck!
# Round: 1
# Please type your choose: rock, paper, scissors, spock or lizard.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a493c6bbcca2> in <module>
#      68     rounds += 1
#      69     print ("Round:", rounds)
# ---> 70     user_input()
#      71     cpu_random()
#      72     print ("Computer:", cpu_choice, "User:",  user_choices )
#
# <ipython-input-4-a493c6bbcca2> in user_input()
#      23     while True:
#      24         print ("Please type your choose: rock, paper, scissors, spock or lizard.")
# ---> 25         user = input()
#      26         global user_choices
#      27         user_choices = user.lower()
#
# ~/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
5 -2

# %%
rounds_choice = []


def number():
    while False:
        try:
            print ("Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).")
            number = input()
            if int(number) / 1:
                print ("Please, type an odd number")
            else:
                continue
        except ValueError: 
            print ("Please, type an odd number")

#def rounds_number():
#    while int(number) % 2 == 0:
 #       print ("Please, type an odd number")
  #  else:
   
        #print ("You choose " + str(number) + " rounds to play. Good luck!" )
     #   global rounds_choice 
      #  rounds_choice = int(number)  
 


 
number()

#rounds_number()

# %%
number = 7
print ("You choose: " + str(number) + ". You need to win at least " + str(number - 5) + " rounds to defeat the computer" )

# %%
# Program to know if number is odd or even

num = int(input("Enter a number: "))

if (num % 2) == 0:
    print(num, " is Even")
else:
    print(num, " is Odd")

# %%
num = int(input("Enter a number: "))
even = (num % 2)
if num != even:
    print("You choose", num, " rounds")
else:
    print ("Please, enter a odd number.")
print (even)

# %%
num = []
a = input("Enter a number: ")
num.append(a)
even = int(num[0]) % 2
print (num[0])
print (int(num[0]) % 2)

# %%
rounds_choice = []


def rounds_number():
    while True:
        print ("Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).")
        global rounds_choice 
        rounds_choice = int(input())
        if (rounds_choice % 2) == 0:
            print ("Please, type an odd number")
        else:
            print ("You choose: " + str(rounds_choice) + "rounds to play. Good luck!" )
            break


    
rounds_number()

# %%
def number():
    while True:
        try:
            print ("Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).")
            number = input()
            if int(number) is False:
                print ("Please, type an odd number")
            elif int(number) % 2 == 0:
                print ("Please, type an odd number")
            else:
                print ("You choose " + str(number) + " rounds to play. Good luck!" )
                global rounds_choice 
                rounds_choice = int(number) 
                break
        except ValueError: 
            print ("Please, type an odd number")
number()
# Out:
# Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).
# l
# Please, type an odd number
# Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).
# l
# Please, type an odd number
# Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).
# 2
# Please, type an odd number
# Please type the number of rounds you want to play. Choose odd numbers (1, 3, 5, 7, etc.).
# 3
# You choose 3 rounds to play. Good luck!

# %%
a= 2


def distance_from_zero():
    if type(a) == int or type(a) == float:
        print (a)
    else:
        print ('Not an integer or a floating point decimal!')

distance_from_zero()
