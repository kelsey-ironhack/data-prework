# %%
gestures = ['rock', 'paper', 'scissors']
player_choose = []

choose = input("Please, write your choose: rock, paper or scissors")

if choose.lower() in gestures[:]:
    player_choose.append(choose.lower())
else:
    print (input("Please, write your choose: rock, paper or scissors"))
    
    
print (player_choose)

# %%
player_choose = []


def ask_player():
    choose = input("Please, write your choose: rock, paper or scissors")
    if choose.lower() in gestures[:]:
        player_choose.append(choose.lower())
    else:
        print (input("Please, write your choose: rock, paper or scissors"))

ask_player()
print (player_choose)

# %%
import random

gestures = ['rock', 'paper', 'scissors']
cpu_choice = []
player_choose = []
cpu_score = 0
player_score = 0

def random_gestures_cpu():
    cpu_choice = random.choice(gestures)
    print (cpu_choice)
    

def ask_player():
    choose = input("Please, write your choose: rock, paper or scissors")
    if choose.lower() in gestures[:]:
        player_choose.append(choose.lower())
    else:
        print (input("Please, write your choose: rock, paper or scissors"))


if random_gestures_cpu() == ask_player():
    print (0)
elif (random_gestures_cpu() == gestures[1]) and (ask_player() == gestures[2]):
    cpu_score += 1

# %%
import random
gestures = ['rock', 'paper', 'scissors']

cpu_choice = " " #[]

def random_gestures_cpu():
    cpu = random.choice(gestures)
    cpu_choice = cpu
    print ("the computer: ", cpu_choice )
    #print ("" .join(cpu_choice))
  
    
random_gestures_cpu()

# %%
gestures = ['rock', 'paper', 'scissors']

user_choice = " " 

def user_input():
    while True:
        print ("Please type your choose: Rock, Paper or Scissors.")
        user = input()
        user_choice = user
        if user_choice in gestures:   #user_choice == gestures[0] or gestures[1] or gestures[2]: # or gestures paper or scissors
            print ("you choosed:", user_choice)
            break
        
        
user_input()      
#print ("You chosed:", user_input()) #break
            
            
print ("done")
print (user_choice)

# %%
gestures = ['rock', 'paper', 'scissors']
print (gestures[0] + gestures[1] + gestures[2])

user = "o"

user2 = " "

user2= user
print (user2)

# %%
user_choice = "paper"
cpu_choice = "scissors"
user_win = 0
cpu_win = 0
#result = 0

def check_round():
    if user_choice == cpu_choice:
        print ("tie")
        result = 0
    elif ((user_choice == "rock") and (cpu_choice == "scissors") or
         (user_choice == "scissors") and (cpu_choice == "paper") or
         (user_choice == "paper") and (cpu_choice == "rock")):
            print ("The user win!")
            result = 2
    else:
        print ("The computer won!")
        result = 1
    
#check_round()    

if check_round() == "The computer won!":
    cpu_win += 1
else:
    user_win += 1
  
        


#elif check_round() == 2:
 #   user_win += 1
        
     
        

print (cpu_win)

# %%
import random

# Game variables
gestures = ['rock', 'paper', 'scissors']



user_choices = ""
cpu_choice = " "

# Welcome to the game
def welcome():
    print ("""
    Welcome to the Python Game
     Rock, Paper & Scissors 
""")
    print ("""
Rules: 
    Rocks beats Scissors
    Scissors beats Paper 
    Paper beats Rock
    
This game has 3 rounds. You need to win 2 to defeat the computer.
Are you ready?
""")
    print (input("Press enter to start with the first round!"))
    

    
def user_input():
    while True:
        print ("Please type your choose: rock, paper or scissors.")
        user = input()
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
            
def cpu_random():
    cpu_choice = random.choice(gestures)
    print ("The computer choose:", cpu_choice)

#welcome()
user_input()
cpu_random() 

print (user_choices) 
print (cpu_choice)

rounds = 0
cpu_score = 0
user_score = 0

while rounds != 3: 
    if ((user_choices == "rock") and (cpu_choice == "scissors") or
        (user_choices == "scissors") and (cpu_choice == "paper") or
        (user_choices == "paper") and (cpu_choice == "rock")):
        print ("The user win!")
        user_score += 1
        rounds += 1 
    elif user_choices == cpu_choice:
        print ("tie")
        cpu_score += 1
        rounds += 1 
    else:
        print ("The computer won!")
        rounds += 1 
        #break
       
    if user_score == 2:
        print ("The user won the game! The cpu:", cpu_score, "The user:", user_score)            
    elif cpu_score == 2:
        print ("The cpu won the game!")
        print ("The cpu:", cpu_score, "The user:", user_score)    
    #elif user_score == cpu_score:
     #   print ("The game is tied!")
      #  print ("The cpu:", cpu_score, "The user:", user_score)    
            
        break
    
    
    



#check_round()

# %%
import random

# definig game variables
gestures = ['rock', 'paper', 'scissors']


user_choices = ""
cpu_choice = ""

rounds = 0
cpu_score = 0
user_score = 0


# Welcome to the game
def welcome():
    print ("""
    Welcome to the Python Game
     Rock, Paper & Scissors 
""")
    print ("""
Rules: 
    Rocks beats Scissors
    Scissors beats Paper 
    Paper beats Rock
    
    This game has 3 rounds. You need to win 2 to defeat the computer.
    Are you ready?
""")
    print (input("Press enter to start with the first round!"))
    

#defining user move 
def user_input():
    while True:
        print ("Please type your choose: rock, paper or scissors.")
        user = input()
        global user_choices 
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
#defining cpu move as random
def cpu_random():
    global cpu_choice 
    cpu_choice = random.choice(gestures)
    print ("The computer choose:", cpu_choice)
    

#welcome()




while rounds < 3: 
    rounds += 1
    print ("Round:", rounds)  
    user_input()
    cpu_random()
    print ("cumputer:", cpu_choice, "User:",  user_choices )
    if user_choices == "rock" and cpu_choice == "scissors":
        print ("The user win! User:", user_score, "Computer:", cpu_score)
        user_score += 1
    elif user_choices == "scissors" and cpu_choice == "paper":
        print ("The user win! User:", user_score, "Computer:", cpu_score)
        user_score += 1
    elif user_choices == "paper" and cpu_choice == "rock":
        print ("The user win! User:", user_score, "Computer:", cpu_score)
        user_score += 1
    elif user_choices == "scissors" and cpu_choice == "paper":
        print ("The computer win! User:", user_score, "Computer:", cpu_score)
        cpu_score += 1
    elif user_choices == "paper" and cpu_choice == "scissors":
        print ("The computer win! User:", user_score, "Computer:", cpu_score)
        cpu_score += 1
    elif user_choices == "rock" and cpu_choice == "papel":
        print ("The computer win! User:", user_scorepa, "Computer:", cpu_score)
        cpu_score += 1
    
    if user_choices == cpu_choice:
        print ("tie")
    elif user_score == 2:
        print ("The user won the game! Computer score:", cpu_score, "   User score:", user_score)            
    elif cpu_score == 2:
        print ("The computer won the game!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        #break

# %%
import random

# definig game variables
gestures = ['rock', 'paper', 'scissors']


user_choices = "global"
cpu_choice = "global"

#defining user move 
def user_input():
    while True:
        print ("Please type your choose: rock, paper or scissors.")
        user = input()
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
#defining cpu move as random
def cpu_random():
    global cpu_choice 
    cpu_choice = random.choice(gestures)
    
    
cpu_random()
    
print ("The fucntion is " ,cpu_choice)
print ("The computer choose:", cpu_choice)

# %%
import random

# definig game variables
gestures = ['rock', 'paper', 'scissors']


user_choices = ""
cpu_choice = ""

rounds = 0
cpu_score = 0
user_score = 0


# Welcome to the game
def welcome():
    print ("""
    Welcome to the Python Game
     Rock, Paper & Scissors 
""")
    print ("""
Rules: 
    Rocks beats Scissors
    Scissors beats Paper 
    Paper beats Rock
    
    This game has 3 rounds. You need to win 2 to defeat the computer.
    Are you ready?
""")
    print (input("Press enter to start with the first round!"))
    

#defining user move 
def user_input():
    while True:
        print ("Please type your choose: rock, paper or scissors.")
        user = input()
        global user_choices 
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
#defining cpu move as random
def cpu_random():
    global cpu_choice 
    cpu_choice = random.choice(gestures)
    print ("The computer choose:", cpu_choice)
    

welcome()




while rounds < 3: 
    rounds += 1
    print ("Round:", rounds)  
    user_input()
    cpu_random()
    print ("cumputer:", cpu_choice, "User:",  user_choices )
    if user_choices == "rock" and cpu_choice == "scissors":
        user_score += 1
        print ("The user win! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and cpu_choice == "paper":
        user_score += 1
        print ("The user win! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and cpu_choice == "rock":
        user_score += 1
        print ("The user win! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and cpu_choice == "paper":
        cpu_score += 1
        print ("The computer win! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and cpu_choice == "scissors":
        cpu_score += 1
        print ("The computer win! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "rock" and cpu_choice == "papel":
        cpu_score += 1
        print ("The computer win! User:", user_scorepa, "Computer:", cpu_score)
        
    
    if user_choices == cpu_choice:
        print ("tie")
    elif user_score == 2:
        print ("The user won the game! Computer score:", cpu_score, "   User score:", user_score) 
        break
    elif cpu_score == 2:
        print ("The computer won the game!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break

# %%
import random

# definig game variables
gestures = ['rock', 'paper', 'scissors']


user_choices = ""
cpu_choice = ""

rounds = 0
cpu_score = 0
user_score = 0
tie = 0


# Welcome to the game
def welcome():
    print ("""
    Welcome to the Python Game
     Rock, Paper & Scissors 
""")
    print ("""
Rules: 
    Rocks beats Scissors
    Scissors beats Paper 
    Paper beats Rock
    
    This game has 3 rounds. You need to win 2 to defeat the computer.
    Are you ready?
""")
    print (input("Press enter to start with the first round!"))
    

#defining user move 
def user_input():
    while True:
        print ("Please type your choose: rock, paper or scissors.")
        user = input()
        global user_choices 
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
#defining cpu move as random
def cpu_random():
    global cpu_choice 
    cpu_choice = random.choice(gestures)
    print ("The computer choose:", cpu_choice)
    

welcome()




while rounds < 3: 
    rounds += 1
    print ("Round:", rounds)  
    user_input()
    cpu_random()
    print ("Computer:", cpu_choice, "User:",  user_choices )
    if user_choices == "rock" and cpu_choice == "scissors":
        user_score += 1
        print ("The user wins the round ! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and cpu_choice == "paper":
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and cpu_choice == "rock":
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and cpu_choice == "paper":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and cpu_choice == "scissors":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "rock" and cpu_choice == "papel":
        cpu_score += 1
        print ("The computer wins the round! User:", user_scorepa, "Computer:", cpu_score)
        
# Print the winner of the game based on who won more rounds
    if user_choices == cpu_choice:
        tie += 1
        print ("tie")
    elif user_score == 2:
        print ("The user wins the game! Computer score:", cpu_score, "   User score:", user_score)   
        break         
    elif cpu_score == 2:
        print ("The computer wins the game!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
    elif tie == 2 or tie == 3:
        print ("The game is tied! Great job!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
    elif tie == 2 and (user_choices == 1 or cpu_choice == 1):

# %%
import random

# definig game variables
gestures = ['rock', 'paper', 'scissors']


user_choices = ""
cpu_choice = ""

rounds = 0
cpu_score = 0
user_score = 0
tie = 0


# Welcome to the game
def welcome():
    print ("""
    Welcome to the Python Game
     Rock, Paper & Scissors 
""")
    print ("""
Rules: 
    Rocks beats Scissors
    Scissors beats Paper 
    Paper beats Rock
    
    This game has 3 rounds. 
    If you want to defeat the computer....
    Then, press enter to start with the first round!
    
""")
    print (input("Are you ready?"))
    

#defining user move 
def user_input():
    while True:
        print ("Please type your choose: rock, paper or scissors.")
        user = input()
        global user_choices 
        user_choices = user.lower()
        if user_choices in gestures:  
            print ("You choose:", user_choices)
            break

            
#defining cpu move as random
def cpu_random():
    global cpu_choice 
    cpu_choice = random.choice(gestures)
    print ("The computer choose:", cpu_choice)
    

welcome()




while rounds < 3: 
    rounds += 1
    print ("Round:", rounds)  
    user_input()
    cpu_random()
    print ("Computer:", cpu_choice, "User:",  user_choices )
    if user_choices == "rock" and cpu_choice == "scissors":
        user_score += 1
        print ("The user wins the round ! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and cpu_choice == "paper":
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and cpu_choice == "rock":
        user_score += 1
        print ("The user wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "scissors" and cpu_choice == "paper":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "paper" and cpu_choice == "scissors":
        cpu_score += 1
        print ("The computer wins the round! User:", user_score, "Computer:", cpu_score)
        
    elif user_choices == "rock" and cpu_choice == "papel":
        cpu_score += 1
        print ("The computer wins the round! User:", user_scorepa, "Computer:", cpu_score)
        
# Print the winner of the game based on who won more rounds
    if user_choices == cpu_choice:
        tie += 1
        print ("tie")
    elif rounds == 3 and (user_score > cpu_score):
        print ("The user wins the game! Computer score:", cpu_score, "   User score:", user_score)   
        break         
    elif rounds == 3 and (user_score < cpu_score):
        print ("The computer wins the game!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
    elif tie == 3:
        print ("The game is tied! Great job!")
        print ("Computer score:", cpu_score, "   User score:", user_score)    
        break
# Out:
#     Welcome to the Python Game
#      Rock, Paper & Scissors
#
#
# Rules:
#     Rocks beats Scissors
#     Scissors beats Paper
#     Paper beats Rock
#
#     This game has 3 rounds.
#     If you want to defeat the computer....
#     Then, press enter to start with the first round!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-837ef8c52c43> in <module>
#      53
#      54
# ---> 55 welcome()
#      56
#      57
#
# <ipython-input-3-837ef8c52c43> in welcome()
#      31
#      32 """)
# ---> 33     print (input("Are you ready?"))
#      34
#      35
#
# ~/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Rock-paper-scissors-lizard-Spock 
 
import random
 
# The key idea of this program is to equate the strings
# "rock", "paper", "scissors", "lizard", "Spock" to numbers
# as follows:
#
# 0 - rock
# 1 - Spock
# 2 - paper
# 3 - lizard
# 4 - scissors
 
# helper functions
 
# convert name to number using if/elif/else
def name_to_number(name):
    if(name == 'rock'):
        return 0;
    elif(name == 'Spock'):
        return 1;
    elif(name == 'paper'):
        return 2;
    elif(name == 'lizard'):
        return 3;
    elif(name == 'scissors'):
        return 4;
    else:
        print ("ERROR Name")
# convert number to a name using if/elif/else
def number_to_name(number):
     
    if(number == 0):
        return 'rock';
    elif(number == 1):
        return 'Spock';
    elif(number == 2):
        return 'paper';
    elif(number == 3):
        return 'lizard';
    elif(number == 4):
        return 'scissors';
    else:
        print ("ERROR Number")
def rpsls(player_choice): 
 
     
    # print a blank line to separate consecutive games
    print ("\n")
     
    # print out the message for the player's choice
    print ("Player chooses " + player_choice)
     
    # convert the player's choice to player_number using the function name_to_number()
    player_number = name_to_number( player_choice )
     
    # compute random guess for comp_number using random.randrange()
    comp_number = random.randrange( 0, 4 )
     
    # convert comp_number to comp_choice using the function number_to_name()
    comp_choice = number_to_name( comp_number );
     
    # print out the message for computer's choice
    print ("Computer chooses " + comp_choice)
     
    # compute difference of comp_number and player_number modulo five
    difference = (comp_number - player_number) % 5
     
    # use if/elif/else to determine winner, print winner message
    if( difference == 1 or difference == 2 ):
        print ("Computer wins!")
    elif ( difference == 4 or difference == 3 ):
        print ("Player wins!")
    elif( difference == 0 ):
        print ("Player and computer tie!")
         
            
# test your code - LEAVE THESE CALLS IN YOUR SUBMITTED CODE
rpsls("rock")
rpsls("Spock")
rpsls("paper")
rpsls("lizard")
rpsls("scissors")
 
# always remember to check your completed program against the grading rubric
# Out:
# Player chooses rock
# Computer chooses lizard
# Player wins!
#
#
# Player chooses Spock
# Computer chooses rock
# Player wins!
#
#
# Player chooses paper
# Computer chooses Spock
# Player wins!
#
#
# Player chooses lizard
# Computer chooses lizard
# Player and computer tie!
#
#
# Player chooses scissors
# Computer chooses Spock
# Computer wins!
