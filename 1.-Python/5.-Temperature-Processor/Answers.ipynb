# %%
temperaturas = [33, 66, 65, 0, 59, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]

#Find the minimum
mínima = min(temperaturas)
print (mínima)
# Out:
# 0

# %%
#Find the maximum
máxima = max(temperaturas)
print (máxima)
# Out:
# 90

# %%
#Create a list with the temperatures that are greater or equal to 70º

altas = []

for i in temperaturas:
    if i >= 70:
        altas.append(i)

print(altas)
# Out:
# [70, 76, 80, 81, 80, 83, 90, 79]

# %%
#Find average temperature

import statistics 
statistics.mean(temperaturas)

Average = statistics.mean(temperaturas)
print (Average)
# Out:
# 60.25

# %%
print (temperaturas)
# Out:
# [33, 66, 65, 0, 59, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]

# %%
#Missing value estimation
newvalue = sum (temperaturas) / 24
print (newvalue)
# Out:
# 60.25

# %%
int(newvalue)
# Out:
# 60

# %%
#Replace value in list
del temperaturas [3]
print (temperaturas)
# Out:
# [33, 66, 65, 59, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]

# %%
temperaturas.insert(3,(int(newvalue)))
print (temperaturas)
# Out:
# [33, 66, 65, 60, 59, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]
