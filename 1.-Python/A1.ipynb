# %% [markdown]
# The Snail and the Well¶
# A snail falls at the bottom of a 125 cm well. Each day the snail rises 30 cm. But at night, while sleeping, slides 20 cm because the walls are wet. How many days does it take for the snail to escape the well?
#
# Hint: The snail gets out of the well when it surpasses the 125cm of height.

# %%
well_height = 125
daily_distance = 30
nightly_distance = 20
snail_position = 0
days = 0
advance_cm = [30, 21, 33, 77, 44, 45, 23, 45, 12, 34, 55]

# %%
while well_height > snail_position :
    snail_position = (snail_position + daily_distance) - nightly_distance
    days = days + 1
else: 
    print('snail is out in', days, 'days')
# Out:
# snail is out in 13 days

# %% [markdown]
# The distance traveled by the snail each day is now defined by a list.
#
# advance_cm = [30, 21, 33, 77, 44, 45, 23, 45, 12, 34, 55]
# On the first day, the snail rises 30cm but during the night it slides 20cm. On the second day, the snail rises 21cm but during the night it slides 20cm, and so on.

# %%
well_height = 125
nightly_distance = 20
snail_position = 0
days = 0
advance_cm = [30, 21, 33, 77, 44, 45, 23, 45, 12, 34, 55]

while well_height > snail_position :
    snail_position = (snail_position + advance_cm[days]) - nightly_distance
    days = days + 1
else: 
    print('snail is out in', days, 'days')
# Out:
# snail is out in 6 days

# %% [markdown]
# 2. What is its maximum displacement in one day? And its minimum? Calculate the displacement using only the travel distance of the days used to get out of the well.

# %%
well_height = 125
nightly_distance = 20
#maximum_displacement = advance_cm [0] - nightly_distance
days = 0
advance_cm = [30, 21, 33, 77, 44, 45]

# %%
list_disp = []

# %%
for cm in advance_cm :
    maximum_displacement =  advance_cm[days] - nightly_distance
    days += 1
    print(maximum_displacement)
# Out:
# 10
# 1
# 13
# 57
# 24
# 25

# %%
for cm in advance_cm :
    maximum_displacement =  advance_cm[days] - nightly_distance
    days += 1
    list_disp.append(maximum_displacement)
    
    
     #max(num_list) 
       # >>> min(num_list)

# %%
print("The maximum displacement is : ",max(list_disp))
# Out:
# The maximum displacement is :  57

# %%
print('The minimum displacement is:', min(list_disp))
# Out:
# The minimum displacement is: 1

# %%
list_disp
# Out:
# [10, 1, 13, 57, 24, 25]

# %% [markdown]
# 3. What is its average progress? Take into account the snail slides at night.

# %%
sum(list_disp)/len(list_disp)
# Out:
# 21.666666666666668

# %% [markdown]
# 4. What is the standard deviation of its displacement? Take into account the snail slides at night.¶

# %%
import statistics

# %%
from statistics import stdev

# %%
stdev(list_disp)
# Out:
# 19.510680835549195
